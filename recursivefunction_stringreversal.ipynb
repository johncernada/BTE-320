# %% [markdown]
# <a href="https://colab.research.google.com/github/johncernada/BTE-320/blob/main/recursivefunction_stringreversal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse(s):
  if len(s) > 1:
    return s[-1] + reverse(s[1:-1]) + s[0]
  else:
    return s

reverse('hello')
# Out:
# 'olleh'
